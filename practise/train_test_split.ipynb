# %%
import pandas as pd

# %%
dataset = pd.read_csv("/content/drive/MyDrive/datasets/HousingData.csv")
dataset.head(3)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7

# %%
input_data = dataset.iloc[:, :-1]
output_data = dataset["MEDV"]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(input_data , output_data , test_size = 0.25)

# %%
# Out:
#         CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS  RAD  TAX  \
# 116  0.13158   0.0  10.01   0.0  0.5470  6.176  72.5  2.7301    6  432
# 225  0.52693   0.0   6.20   0.0  0.5040  8.725  83.0  2.8944    8  307
# 169  2.44953   0.0  19.58   0.0  0.6050  6.402  95.2  2.2625    5  403
# 393      NaN   0.0  18.10   0.0  0.6930  6.193  92.6  1.7912   24  666
# 165  2.92400   0.0  19.58   0.0  0.6050  6.101  93.0  2.2834    5  403
# ..       ...   ...    ...   ...     ...    ...   ...     ...  ...  ...
# 204  0.02009  95.0   2.68   0.0  0.4161  8.034  31.9  5.1180    4  224
# 448  9.32909   0.0  18.10   0.0  0.7130  6.185  98.7  2.2616   24  666
# 66   0.04379  80.0   3.37   0.0  0.3980  5.787  31.1  6.6115    4  337
# 304  0.05515  33.0   2.18   0.0  0.4720  7.236  41.1  4.0220    7  222
# 301  0.03537   NaN   6.09   0.0  0.4330  6.590  40.4  5.4917    7  329
#
#      PTRATIO       B  LSTAT
# 116     17.8  393.30    NaN
# 225     17.4  382.00   4.63
# 169     14.7  330.04  11.32
# 393     20.2  396.90  15.17
# 165     14.7  240.16   9.81
# ..       ...     ...    ...
# 204     14.7  390.55   2.88
# 448     20.2  396.90  18.13
# 66      16.1  396.90  10.24
# 304     18.4  393.68   6.93
# 301     16.1  395.75   9.50
#
# [379 rows x 13 columns]

# %%
x_train.shape , y_train.shape , x_test.shape , y_test.shape
# Out:
# ((379, 13), (379,), (127, 13), (127,))
